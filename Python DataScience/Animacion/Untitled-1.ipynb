# %%
import seaborn as sns
import pandas as pd
import matplotlib.animation as ani
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("sunspot_data.csv")
df.head()
# Out:
#    Unnamed: 0  Year  Month  Day  Date In Fraction Of Year  Number of Sunspots  \
# 0           0  1818      1    1                  1818.001                  -1
# 1           1  1818      1    2                  1818.004                  -1
# 2           2  1818      1    3                  1818.007                  -1
# 3           3  1818      1    4                  1818.010                  -1
# 4           4  1818      1    5                  1818.012                  -1
#
#    Standard Deviation  Observations  Indicator
# 0                -1.0             0          1
# 1                -1.0             0          1
# 2                -1.0             0          1
# 3                -1.0             0          1
# 4                -1.0             0          1

# %%
df.info()
df = df[df["Year"] > 1980]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73718 entries, 0 to 73717
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                73718 non-null  int64
#  1   Year                      73718 non-null  int64
#  2   Month                     73718 non-null  int64
#  3   Day                       73718 non-null  int64
#  4   Date In Fraction Of Year  73718 non-null  float64
#  5   Number of Sunspots        73718 non-null  int64
#  6   Standard Deviation        73718 non-null  float64
#  7   Observations              73718 non-null  int64
#  8   Indicator                 73718 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 5.1 MB

# %%
y = df["Number of Sunspots"]
x = df["Date In Fraction Of Year"]
sns.displot(data=df, x="Date In Fraction Of Year", y="Number of Sunspots",kind="kde")

# %%
df2 = pd.read_csv("dielectron.csv")
df2.head()
# Out:
#       Run      Event        E1      px1         py1       pz1       pt1  \
# 0  147115  366639895  58.71410  -7.31132  10.531000 -57.29740  12.82020
# 1  147115  366704169   6.61188  -4.15213  -0.579855  -5.11278   4.19242
# 2  147115  367112316  25.54190 -11.48090   2.041680  22.72460  11.66100
# 3  147115  366952149  65.39590   7.51214  11.887100  63.86620  14.06190
# 4  147115  366523212  61.45040   2.95284 -14.622700 -59.61210  14.91790
#
#       eta1     phi1  Q1       E2        px2      py2      pz2       pt2  \
# 0 -2.20267  2.17766   1  11.2836  -1.032340 -1.88066 -11.0778   2.14537
# 1 -1.02842 -3.00284  -1  17.1492 -11.713500  5.04474  11.4647  12.75360
# 2  1.42048  2.96560   1  15.8203  -1.472800  2.25895 -15.5888   2.69667
# 3  2.21838  1.00721   1  25.1273   4.087860  2.59641  24.6563   4.84272
# 4 -2.09375 -1.37154  -1  13.8871  -0.277757 -2.42560 -13.6708   2.44145
#
#        eta2      phi2  Q2         M
# 0 -2.344030 -2.072810  -1   8.94841
# ...

# %%
sns.displot(data=df2[:int(len(df2)/6)], x= "E1", y="py1", kind="kde")
